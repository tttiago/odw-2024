# %% [markdown]
# <span style="float: left;padding: 1.3em">![logo](https://github.com/tttiago/odw-2024/blob/main/Tutorials/logo.png?raw=1)</span>
#
#
# #  Gravitational Wave Open Data Workshop #7
#
#
# ## Tutorial 3.1: An introduction to parameter estimation
#
# In this tutorial, we will introduce Bayesian inference and "parameter estimation", a crucial part of gravitational wave astronomy. We will start with a general introduction to inference, the idea of stochastic sampling, and then introduce the
# [bilby Bayesian inference library](https://lscsoft.docs.ligo.org/bilby/).
#
#
# [Click this link to view this tutorial in Google Colaboratory](https://colab.research.google.com/github/gw-odw/odw-2024/blob/main/Tutorials/Day_3/Tuto_3.1_Introduction_to_parameter_estimation.ipynb)

# %% [markdown]
# ## Installation

# %%
# -- Use the following line in Google Colab
! pip install -q bilby==2.2.2 matplotlib==3.7.3 dynesty==2.1.2 corner==2.2.2
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 46.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 940.1/940.1 kB 23.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 kB 1.2 MB/s eta 0:00:00

# %% [markdown]
# **Important:** With Google Colab, you may need to restart the runtime after running the cell above.

# %% [markdown]
# ### Download sample data
#
# If you are running on Google Colab, or another environment which copies the notebook but not the sample data. Please run the following cell. (Note: you may also download the file directly).

# %%
import os
if not os.path.isfile("toy_model.csv"):
  print("Downloading toy_model.csv")
  ! wget https://raw.githubusercontent.com/tttiago/odw-2024/main/Tutorials/Day_3/toy_model.csv
else:
  print("toy_model.csv exists; not downloading")
# Out:
# Downloading toy_model.csv
# --2024-09-19 13:53:48--  https://raw.githubusercontent.com/tttiago/odw-2024/main/Tutorials/Day_3/toy_model.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5104 (5.0K) [text/plain]
# Saving to: ‘toy_model.csv’
#
# toy_model.csv       100%[===================>]   4.98K  --.-KB/s    in 0s
#
# 2024-09-19 13:53:48 (64.3 MB/s) - ‘toy_model.csv’ saved [5104/5104]

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import bilby
import corner

for module in [np, matplotlib, bilby, corner]:
    print(f"Loaded {module.__name__}: {module.__version__}")
# Out:
# Loaded numpy: 1.26.4
# Loaded matplotlib: 3.7.1
# Loaded bilby: 2.2.2
# Loaded corner: 2.2.2

# %% [markdown]
# ### Bayesian inference
#
# Let us assume we are given some data $d$ and we wish to use the data to learn about a model $M$ with associated parameters $\theta$. Bayes' theorem provides a framework to do this. Namely, the *posterior* probability distribution of the parameters $\theta$ can be calculated from
#
# $$ p(\theta | d, M) = \frac{\mathcal{L}(d| \theta, M) \;\pi(\theta | M)}{\mathcal{Z}(d | M)} $$
#
# where $\mathcal{L}(d| \theta, M)$ is the *likelihood*, $\pi(\theta | M)$ is the *prior* probability distribution, and $\mathcal{Z}(d | M)$ is the *evidence* (or fully marginalized likelihood) which normalized the posterior, i.e.
#
# $$ \mathcal{Z}(d | M) = \int \mathcal{L}(d| \theta, M) \;\pi(\theta | M)\, d\theta $$
#
# For most interesting problems, the posterior and evidence (i.e. $p(\theta | d, M) $ and $\mathcal{Z}(d | M) $) cannot be calculated in closed form. Instead we rely on computational methods to approximate them - in this tutorials we will use **stochastic sampling**.
#
# Approximating $p(\theta | d, M)$ is known as **parameter estimation** for obvious reasons. However, let us briefly note that Bayesian inference also extends to **model comparison** as follows. If we have two models, say $M_A$ and $M_B$, then Bayes theorem also tells us that
#
# $$ \frac{P(M_A | d)}{P(M_B | d)} = \frac{\mathcal{Z}(d | M_A)}{\mathcal{Z}(d | M_B)} \frac{\pi(M_A)}{\pi(M_B)} $$
#
# This ratio known as the *posterior odds* compares the relative probability of each model. If it is greater than 1 this implies evidence for $M_A$ whereas if it is less than 1 it implies evidence for $M_B$. The right hand side is the product of the *Bayes factor* $\frac{\mathcal{Z}(d | M_A)}{\mathcal{Z}(d | M_B)}$ (which can be estimated using stochastic sampling) and the *prior odds* $\frac{\pi(M_A)}{\pi(M_B)}$.

# %% [markdown]
# ### Introducing a toy model
#
# In order to introduce the basics of Bayesian inference and stochastic sampling, let us introduce some example data and then a toy model with parameters for us to estimate. In this repository, we include our data `toy_model.csv`. This is a text file containing an observed timeseries of `yobs` recorded at times `time`. We now read in the data and plot it

# %%
time, yobs = np.genfromtxt("toy_model.csv", delimiter=",").T
fig, ax = plt.subplots()
ax.plot(time, yobs)
ax.set(xlabel="Time [s]", ylabel="Observed y values [arb. units]")
plt.show()

# %% [markdown]
# We are told by our tame theoretician, that a good model to explain this data is a so-called *sine Gaussian* which consists of a sinusoidal function modulated with a Gaussian-exponential envelope, i.e.
#
# $$ M_s: s(t) = e^{-(t/\alpha)^2} \sin\left(2\pi f t\right)  $$
#
# where $M_s$ will be our label for the sine-Gaussian model. This model has two parameters $f$ and $\alpha$; we could further generalise this to have an arbitrary amplitude, phase shift, or time shift, as well but here we introduce the simple two-parameter model for illustration.
#
# Before we go any further, let's check that we understand the model by plotting it out with some arbitrary choices for $f$ and $\alpha$. To do this, we will create some functions that we can use later on. We plot the full function and the individual components to help visualise it.

# %%
def sinusoid(time, freq):
    return np.sin(2 * np.pi * freq * time)


def gaussian_exponential(time, alpha):
    return np.exp(-(time/alpha)**2)


def model_Ms(time, freq, alpha):
    return gaussian_exponential(time, alpha) * sinusoid(time, freq)

freq = 2
alpha = 0.5

fig, ax = plt.subplots()

ax.plot(time, sinusoid(time, freq), label="Sinusoid")
ax.plot(time, gaussian_exponential(time, alpha), label="Gaussian exponential")
ax.plot(time, model_Ms(time, freq, alpha), label="Sine Gaussian")
ax.set(xlabel="Time [s]", ylabel="Observed y values [arb. units]")
ax.legend()
plt.show()

# %% [markdown]
# ### Parameter Estimation
#
# Now that we have our data (`yobs`) and our model $M_s$, our task is to estimate the parameters $f$ and $\alpha$. To do this, we will use Bayes theorem, i.e. we want to approximate the distribution
#
# $$ p(\theta | d, M_s) = \frac{\mathcal{L}(d| \theta, M_s) \;\pi(\theta | M_s)}{\mathcal{Z}(d | M_s)} $$
#
# where $\theta=\{f, \alpha\}$ is the two-dimensional parameter vector and $d$ is `yobs` (measured at times `time`). To this end, we need to define the likelihood and priors. Note that, if we are **only interested in the shape of the distribution**, then we can ignore the evidence, i.e. we can estimate the unnormalized distribution
#
# $$ p(\theta | d, M_s) \propto \mathcal{L}(d| \theta, M_s) \;\pi(\theta | M_s) $$
#
# Before proceeding, we need to define our likelihood and prior.
#
# #### Parameter Estimation: Likelihood
#
# For this toy example, we will assume that the data consists of the generate model $M_s$ and additive white Gaussian noise, i.e.
#
# $$ y_{\rm obs}(t) = s(t; f, \alpha) + \epsilon $$
#
# where $\epsilon \sim N(0, \sigma)$ by which we mean that $\epsilon$ is drawn from a Gaussian distribution with zero mean and standard deviation $\sigma=0.1$ (for now, we will assume this is known a priori, but see challenges below for how it could be estimated).
#
# This definition of how the data was created allows us to define our likelihood. Namely, given a value of $\{f, \alpha\}$, the likelihood of a single data point $y_i$ (measured at $t_i$) is:
#
# $$ \mathcal{L}(y_i| f, \alpha, M_s) = \frac{1}{\sqrt{2\pi \sigma^2}} \exp\left(-\frac{(y_i - s(t_i; f, \alpha))^2}{2\sigma^2}\right) $$
#
# To extend this to multiple data points, we assume they are independent then
#
# $$ \mathcal{L}(y_{obs} | f, \alpha, M_s) = \prod_i \mathcal{L}(y_i| f, \alpha, M_s) $$
#
# In practice, it is wise to work with the logarithm of the likelihood to avoid numerical overflow. Then, we have that
#
# $$ \log \mathcal{L}(y_{obs} | f, \alpha, M_s) = \sum_{i} -\frac{1}{2}\left(\frac{\left(y_i - s(t_i; f, \alpha)\right)^2}{\sigma^2} + \log\left(2\pi \sigma^2\right)\right) $$
#
# We now transcribe this into `python`:

# %%
def log_likelihood_Ms(time, yobs, freq, alpha, sigma=0.1):
    prediction = model_Ms(time, freq, alpha)
    res = yobs - prediction
    logl = -0.5 * (((res/sigma)**2) + np.log(2 * np.pi * sigma**2))
    # Sum over all log_likelihoods (axis=0)
    return np.sum(logl, axis=0)

# %% [markdown]
# #### Parameter Estimation: Priors
#
# The second part of Bayes theorem is the *prior*. For our two-component model, we will use a simple disjoint prior (i.e. $\pi(\theta | M_s)=\pi(f| M_s)\pi(\alpha | M_s)$) with
#
# $$ \pi(f| M_s) = \textrm{Uniform}(0, 5) $$
# $$ \pi(\alpha| M_s) = \textrm{Uniform}(0, 1) $$
#
# Let us create a python function to calculate the log of the prior:

# %%
def log_prior_Ms(freq, alpha):
    """ Calculate the log prior under the Ms model

    Parameters
    ----------
    freq: array or float
        The frequency at which to calculate the prior
    alpha: array or float
        The alpha at which to calculate the prior

    Returns
    -------
    log_prior: array
        The log_prior calculated for all freq, alpha samples
    """
    # Convert freq, alpha to numpy arrays
    freq = np.atleast_1d(freq)
    alpha = np.atleast_1d(alpha)

    # Apply Uniform priors: calculate idxs of array where f, alpha in range
    f_min = 0
    f_max = 5
    f_idxs = (freq > f_min) * (freq < f_max)

    alpha_min = 0
    alpha_max = 1
    alpha_idxs = (alpha > alpha_min) * (alpha < alpha_max)

    idxs = alpha_idxs * f_idxs

    log_prior_volume = np.log(1/(f_max - f_min) * (1 / (alpha_max - alpha_min)))

    log_prior = np.zeros_like(freq)
    log_prior[idxs] = log_prior_volume
    log_prior[~idxs] = -np.inf
    return log_prior

# %% [markdown]
# #### Parameter Estimation: Rejection Sampling
#
# Now that we have our likelihood and prior, we will introduce **stochastic sampling**. We start by using the simplest type of stochastic sampling, rejection sampling. The idea is that to draw samples from a target distribution $p(\theta | d, M_s)$ which is difficult to sample from, we first generate samples from a generating distribution $g(\theta$) which is easy to sample from and then weight the samples relative to the target distribution. In practice you can choose any generating distribution you like, but we will use $g(\theta) = g(f)g(\alpha)$ where
#
# $$ g(f) = \textrm{Uniform}(1.8, 2.2) $$
# $$ g(\alpha) = \textrm{Uniform}(0.2, 0.6) $$
#
# Our rejection sampling algorithm then proceeds as follows:
#
#
# 1. Draw $\theta'=[f, \alpha]$ from $g(f)$ and $g(\alpha)$
# 2. Calculate the probability under the target and generating distributions (i.e. $p(\theta' | d, M_s)$ and $g(\theta')$)
# 3. Calculate the weight $w=p(\theta' | d, M_s) / g(\theta')$
# 4. Draw a random number $u$ uniformly distributed in $[0, 1]$
# 5. If $w > u$, append $\theta'$ to a set of samples, otherwise reject it and repeat
#
# Continue this loop until an acceptable number of samples have been drawn. The resulting set of samples are then an approximation to $p(\theta | d, M_s)$ and be used to produce summary statistics or create plots.
#
# We now program the algorithm for our test data. However, there are two important differences between this algorithm and the expression above:
#
# 1. We will work with the unnormalised distribution $p(\theta | d, M_s)$ (i.e. we don't calculate the evidence $\mathcal{Z}$. As a result, $w$ is also unnormalised and so it needs to be normalised before we apply step 5. Fortunately, we can normalize $w$ once we have a distribution of values.
# 2. For computational efficiency, rather than using a while loop we will instead draw a set of 100000 samples, calculate the weights for each, and then apply rejection sampling. This utilises numpy array optimization and also enables us to normalise the weights to a distribution.

# %%
# Draw 10000 samples from g(theta)
N = 100000
freq_gsamples = np.random.uniform(1.8, 2.2, N)
alpha_gsamples = np.random.uniform(0.2, 0.6, N)

# Make time a 2D array to enable broadcasting across the samples
time_array = time[:, np.newaxis]
yobs_array = yobs[:, np.newaxis]

# Calculate the log_likelihood and log_prior for all samples
log_likelihood_vals = log_likelihood_Ms(time_array, yobs_array, freq_gsamples, alpha_gsamples)
log_prior_vals = log_prior_Ms(freq_gsamples, alpha_gsamples)
log_posterior_vals = log_likelihood_vals + log_prior_vals

# Calculate the weights
weights = np.exp(log_posterior_vals)

# Normalise the weights
weights = weights / max(weights)

# Rejection sample
keep = weights > np.random.uniform(0, 1, weights.shape)
alpha_samples = alpha_gsamples[keep]
freq_samples = freq_gsamples[keep]

# %% [markdown]
# The end result of this is a set of samples `freq_samples` and `alpha_samples` that approximate the posterior distribution. We can get a quick visualisation of these by using the `corner` package:

# %%
# Create a corner plot
samples = np.array([freq_samples, alpha_samples]).T
fig = corner.corner(samples, bins=20, labels=["f", "alpha"], show_titles=True, quantiles=[0.16, 0.5, 0.84],)

# %% [markdown]
# The plot above shows two 1D histograms (one for each parameter) and one 2D histogram (showing any correlations between the samples). Areas where the posterior is large (i.e. the histogram count is high) represent the most probable values of $f$ and $\alpha$ which explain the data.
#
# The samples can also be used to provide a summary statistic. For example, if you wanted to report the mean and standard deviation interval for $f$, you could do something like this:

# %%
mean_f = np.mean(freq_samples)
std_f = np.std(freq_samples)
print(f"We estimate the the mean and standard deviation of frequency to be {mean_f:0.2f}+/-{std_f:0.2f}")
# Out:
# We estimate the the mean and standard deviation of frequency to be 1.94+/-0.04

# %% [markdown]
# Typically, in GW astronomy, we use the median and a 90\% credible interval because the posterior is often non-symmetric.

# %% [markdown]
# In this exerise, we have learned that rejection sampling can be used to approximate the posterior distribution. However, we should note that it is highly inefficienct. It works okay here, because we tightly tuned the edges of $g(\theta)$, but if you go back and increase these to a wider range, you'll see the efficiency quickly drops off. Moreover, the efficiency of rejection sampling also suffers when we start to look at problems in more than 2 parameters.

# %%
# To calculate the efficiency
efficiency = len(freq_samples) / len(freq_gsamples)
print(efficiency)
# Out:
# 0.02538

# %% [markdown]
# #### Parameter Estimation: Markov Chain Monte Carlo
#
# The rejection sampling algorithm is inefficient in problems where the posterior is small compared to the prior volume. To address this, a range of stochastic sampling algorithms are available. In GW astronomy, two are preferred: Markov Chain Monte Carlo (MCMC), and Nested Sampling. We will now introduce `bilby` which is an inference package allowing access to several off the shelf samplers.
#
# `bilby` has helper functionality to program up our likelihood and prior. We begin by using that:

# %%
likelihood_Ms = bilby.core.likelihood.GaussianLikelihood(time, yobs, model_Ms, sigma=0.1)

priors_Ms = dict(
    freq=bilby.core.prior.Uniform(0, 5),
    alpha=bilby.core.prior.Uniform(0, 1)
)

# %% [markdown]
# This creates two objects, a `likelihood` and `prior`. These can now be passed to `run_sampler` with some options to select the `bilby_mcmc` sampler and configure it in a way that is efficient for this problem.

# %%
result_Ms = bilby.run_sampler(
    likelihood_Ms,
    priors_Ms,
    label="model_Ms",  # A label to help sort our results
    outdir="toy_model",  # The directory where results will be kept
    clean=True,  # Don't use cached data
    sampler="bilby_mcmc",  # Use the bilby_mcmc sampler
    nsamples=1000,  # Draw 1000 samples
    printdt=2,  # Print an update ever 5 seconds
    L1steps=1,  # The number of internal steps to take
)
# Out:
# 13:54 bilby INFO    : Running for label 'model_Ms', output will be saved to 'toy_model'
# /usr/local/lib/python3.10/dist-packages/_distutils_hack/__init__.py:32: UserWarning: Setuptools is replacing distutils. Support for replacing an already imported distutils is deprecated. In the future, this condition will fail. Register concerns at https://github.com/pypa/setuptools/issues/new?template=distutils-deprecation.yml
#   warnings.warn(
# 13:54 bilby INFO    : Analysis priors:
# 13:54 bilby INFO    : freq=Uniform(minimum=0, maximum=5, name=None, latex_label=None, unit=None, boundary=None)
# 13:54 bilby INFO    : alpha=Uniform(minimum=0, maximum=1, name=None, latex_label=None, unit=None, boundary=None)
# 13:54 bilby INFO    : Analysis likelihood class: <class 'bilby.core.likelihood.GaussianLikelihood'>
# 13:54 bilby INFO    : Analysis likelihood noise evidence: nan
# 13:54 bilby INFO    : Single likelihood evaluation took 6.957e-04 s
# 13:54 bilby INFO    : Using sampler Bilby_MCMC with kwargs {'nsamples': 1000, 'nensemble': 1, 'pt_ensemble': False, 'ntemps': 1, 'Tmax': None, 'Tmax_from_SNR': 20, 'initial_betas': None, 'adapt': True, 'adapt_t0': 100, 'adapt_nu': 10, 'pt_rejection_sample': False, 'burn_in_nact': 10, 'thin_by_nact': 1, 'fixed_discard': 0, 'autocorr_c': 5, 'L1steps': 1, 'L2steps': 3, 'printdt': 2, 'check_point_delta_t': 1800, 'min_tau': 1, 'proposal_cycle': 'default', 'stop_after_convergence': False, 'fixed_tau': None, 'tau_window': None, 'evidence_method': 'stepping_stone', 'initial_sample_method': 'prior', 'initial_sample_dict': None}
# 13:54 bilby INFO    : Initializing BilbyPTMCMCSampler with:
#   Convergence settings: ConvergenceInputs(autocorr_c=5, burn_in_nact=10, thin_by_nact=1, fixed_discard=0, target_nsamples=1000, stop_after_convergence=False, L1steps=1, L2steps=3, min_tau=1, fixed_tau=None, tau_window=None)
#   Parallel-tempering settings: ParallelTemperingInputs(ntemps=1, nensemble=1, Tmax=None, Tmax_from_SNR=20, initial_betas=None, adapt=True, adapt_t0=100, adapt_nu=10, pt_ensemble=False)
#   proposal_cycle: default
#   pt_rejection_sample: False
# 13:54 bilby INFO    : Setting parallel tempering inputs=ParallelTemperingInputs(ntemps=1, nensemble=1, Tmax=None, Tmax_from_SNR=20, initial_betas=None, adapt=True, adapt_t0=100, adapt_nu=10, pt_ensemble=False)
# 13:54 bilby INFO    : Initializing BilbyPTMCMCSampler with:ntemps=1, nensemble=1, pt_ensemble=False, initial_betas=[1], initial_sample_method=prior, initial_sample_dict=None
#
# 13:54 bilby INFO    : Using initial sample {'freq': 2.794107507987192, 'alpha': 0.16514666389560728}
# 13:54 bilby INFO    : Using ProposalCycle:
#   AdaptiveGaussianProposal(acceptance_ratio:nan,n:0,scale:1,)
#   DifferentialEvolutionProposal(acceptance_ratio:nan,n:0,)
#   UniformProposal(acceptance_ratio:nan,n:0,)
#   KDEProposal(acceptance_ratio:nan,n:0,trained:0,)
#   FisherMatrixProposal(acceptance_ratio:nan,n:0,scale:1,)
#   GMMProposal(acceptance_ratio:nan,n:0,trained:0,)
#
# 13:54 bilby INFO    : Setting convergence_inputs=ConvergenceInputs(autocorr_c=5, burn_in_nact=10, thin_by_nact=1, fixed_discard=0, target_nsamples=1000, stop_after_convergence=False, L1steps=1, L2steps=3, min_tau=1, fixed_tau=None, tau_window=None)
# 13:54 bilby INFO    : Drawing 1000 samples
# 13:54 bilby INFO    : Checkpoint every check_point_delta_t=1800s
# 13:54 bilby INFO    : Print update every printdt=2s
# 2.08e+03|0:00:02|1.56e+03(10tau)|t=22|n=23|a=0.20|e=1.1e+00%|0.96ms/ev|maxl=25.99|ETF=0:00:20
# 13:54 bilby WARNING : Non-negligible print progress time (ppt_frac=0.08)
# 4.06e+03|0:00:04|4.37e+02(z1)|t=22|n=164|a=0.21|e=4.0e+00%|1.01ms/ev|maxl=25.99|ETF=0:00:18
# 4.46e+03|0:00:06|4.37e+02(z1)|t=22|n=181|a=0.22|e=4.1e+00%|7.46ms/ev|maxl=25.99|ETF=0:02:15
# 13:54 bilby WARNING : Non-negligible print progress time (ppt_frac=0.01)
# 4.77e+03|0:00:08|4.37e+02(z1)|t=22|n=196|a=0.24|e=4.1e+00%|6.45ms/ev|maxl=25.99|ETF=0:01:54
# 4.94e+03|0:00:10|4.37e+02(z1)|t=22|n=203|a=0.25|e=4.1e+00%|12.03ms/ev|maxl=25.99|ETF=0:03:31
# 5.12e+03|0:00:12|4.37e+02(z1)|t=22|n=211|a=0.26|e=4.1e+00%|10.89ms/ev|maxl=25.99|ETF=0:03:09
# 5.35e+03|0:00:14|4.37e+02(z1)|t=22|n=222|a=0.28|e=4.1e+00%|8.74ms/ev|maxl=25.99|ETF=0:02:30
# 5.84e+03|0:00:16|4.37e+02(z1)|t=22|n=244|a=0.30|e=4.2e+00%|4.10ms/ev|maxl=25.99|ETF=0:01:08
# 6.24e+03|0:00:19|4.37e+02(z1)|t=22|n=262|a=0.32|e=4.2e+00%|5.08ms/ev|maxl=25.99|ETF=0:01:22
# 13:54 bilby WARNING : Non-negligible print progress time (ppt_frac=0.01)
# 6.80e+03|0:00:21|4.37e+02(z1)|t=22|n=287|a=0.35|e=4.2e+00%|3.60ms/ev|maxl=25.99|ETF=0:00:56
# 13:54 bilby WARNING : Non-negligible print progress time (ppt_frac=0.01)
# 7.01e+03|0:00:23|4.37e+02(z1)|t=22|n=297|a=0.36|e=4.2e+00%|9.57ms/ev|maxl=25.99|ETF=0:02:28
# 13:54 bilby WARNING : Non-negligible print progress time (ppt_frac=0.03)
# 7.22e+03|0:00:25|4.37e+02(z1)|t=22|n=306|a=0.37|e=4.2e+00%|9.66ms/ev|maxl=25.99|ETF=0:02:28
# 7.67e+03|0:00:27|4.37e+02(z1)|t=22|n=327|a=0.38|e=4.3e+00%|4.46ms/ev|maxl=25.99|ETF=0:01:06
# 7.96e+03|0:00:29|4.37e+02(z1)|t=22|n=340|a=0.39|e=4.3e+00%|6.83ms/ev|maxl=25.99|ETF=0:01:39
# 8.42e+03|0:00:31|4.37e+02(z1)|t=22|n=361|a=0.40|e=4.3e+00%|4.38ms/ev|maxl=25.99|ETF=0:01:01
# 13:54 bilby WARNING : Non-negligible print progress time (ppt_frac=0.01)
# 9.12e+03|0:00:33|4.37e+02(z1)|t=22|n=392|a=0.42|e=4.3e+00%|2.90ms/ev|maxl=25.99|ETF=0:00:38
# 9.68e+03|0:00:35|4.37e+02(z1)|t=22|n=418|a=0.43|e=4.3e+00%|3.53ms/ev|maxl=25.99|ETF=0:00:45
# 1.06e+04|0:00:37|4.37e+02(z1)|t=22|n=459|a=0.44|e=4.3e+00%|2.22ms/ev|maxl=25.99|ETF=0:00:26
# 1.11e+04|0:00:39|4.37e+02(z1)|t=22|n=484|a=0.45|e=4.3e+00%|3.66ms/ev|maxl=25.99|ETF=0:00:41
# 1.26e+04|0:00:41|4.37e+02(z1)|t=22|n=549|a=0.47|e=4.4e+00%|1.39ms/ev|maxl=25.99|ETF=0:00:13
# 1.44e+04|0:00:43|4.37e+02(z1)|t=22|n=632|a=0.48|e=4.4e+00%|1.09ms/ev|maxl=25.99|ETF=0:00:08
# 1.52e+04|0:00:45|4.37e+02(z1)|t=22|n=666|a=0.49|e=4.4e+00%|2.65ms/ev|maxl=25.99|ETF=0:00:19
# 1.56e+04|0:00:47|4.37e+02(z1)|t=22|n=688|a=0.49|e=4.4e+00%|4.32ms/ev|maxl=25.99|ETF=0:00:29
# 1.61e+04|0:00:49|4.37e+02(z1)|t=22|n=710|a=0.50|e=4.4e+00%|4.05ms/ev|maxl=25.99|ETF=0:00:25
# 1.64e+04|0:00:51|4.37e+02(z1)|t=22|n=720|a=0.50|e=4.4e+00%|8.70ms/ev|maxl=25.99|ETF=0:00:53
# 1.67e+04|0:00:53|4.37e+02(z1)|t=22|n=733|a=0.50|e=4.4e+00%|7.07ms/ev|maxl=25.99|ETF=0:00:41
# 1.71e+04|0:00:55|4.37e+02(z1)|t=9|n=1868|a=0.50|e=1.1e+01%|4.85ms/ev|maxl=25.99|ETF=0
# 13:55 bilby WARNING : Non-negligible print progress time (ppt_frac=0.02)
# 13:55 bilby INFO    : Reached convergence: exiting sampling
# 13:55 bilby INFO    : Checkpoint start
# 13:55 bilby INFO    : Written checkpoint file toy_model/model_Ms_resume.pickle
# 13:55 bilby INFO    : Zero-temperature proposals:
# 13:55 bilby INFO    : AdaptiveGaussianProposal(acceptance_ratio:0.22,n:2.9e+03,scale:0.031,)
# 13:55 bilby INFO    : DifferentialEvolutionProposal(acceptance_ratio:0.48,n:3.4e+03,)
# 13:55 bilby INFO    : UniformProposal(acceptance_ratio:1,n:1.2e+02,)
# 13:55 bilby INFO    : KDEProposal(acceptance_ratio:0.63,n:3.7e+03,trained:1,)
# 13:55 bilby INFO    : FisherMatrixProposal(acceptance_ratio:0.53,n:3.2e+03,scale:1,)
# 13:55 bilby INFO    : GMMProposal(acceptance_ratio:0.58,n:3.8e+03,trained:1,)
# 13:55 bilby INFO    : Current taus={'freq': 7.3, 'alpha': 8.9}
# 13:55 bilby INFO    : Creating diagnostic plots
# 13:55 bilby INFO    : Checkpoint finished
# 13:55 bilby INFO    : Sampling time: 0:00:55.186851
# 13:55 bilby INFO    : Summary of results:
# nsamples: 2079
# ln_noise_evidence:    nan
# ln_evidence:    nan +/-    nan
# ln_bayes_factor:    nan +/-    nan

# %% [markdown]
# The `run_sampler` method returns an object `result`. This contains all the interesting information that we might want to use. It also has methods we can use. For example, let's create a corner plot.

# %%
result_Ms.plot_corner()

# %% [markdown]
# We can also get to the samples, which are stored as a `pandas` data frame, as follows

# %%
result_Ms.posterior
# Out:
#           freq     alpha  log_likelihood  log_prior
# 0     1.915037  0.367759       24.960908  -1.609438
# 1     1.915037  0.367759       24.960908  -1.609438
# 2     1.915037  0.367759       24.960908  -1.609438
# 3     1.915037  0.367759       24.960908  -1.609438
# 4     1.956954  0.354572       25.782280  -1.609438
# ...        ...       ...             ...        ...
# 2074  1.999535  0.323976       24.006761  -1.609438
# 2075  1.914339  0.370128       24.759339  -1.609438
# 2076  1.946708  0.357587       25.751557  -1.609438
# 2077  1.975887  0.344126       25.592503  -1.609438
# 2078  1.930050  0.379270       24.029763  -1.609438
#
# [2079 rows x 4 columns]

# %% [markdown]
# Let's compare our rejection sampling results with the `bilby_mcmc` results. To do this, we will create a histogram of the $f$ samples for both:

# %%
fig, ax = plt.subplots()
ax.hist(freq_samples, density=True, bins=50, label="Rejection Sampling", alpha=0.8)
ax.hist(result_Ms.posterior["freq"], density=True, bins=50, label="bilby_mcmc", alpha=0.5)
ax.set(xlabel="f", ylabel="Density")
plt.legend()
plt.show()

# %% [markdown]
# They lie on top of each other: this indicates that, within sampling errors, they are producing identical results.

# %% [markdown]
# ## Challenge Questions
#
# ### Q1.1
# To quantify agreement between distributions,  it is often useful to calculate a summary statistic and show they agree. Calculate the mean and standard deviation from the rejection sampling algorithm **and** the `bilby_mcmc` approach for both $f$ and $\alpha$. Do they agree to within the quoted standard deviation?

# %%
mean_a = alpha_samples.mean()
std_a = alpha_samples.std()

mean_f_bilby = result_Ms.posterior["freq"].mean()
mean_a_bilby = result_Ms.posterior["alpha"].mean()
std_f_bilby = result_Ms.posterior["freq"].std()
std_a_bilby = result_Ms.posterior["alpha"].std()

print(f"freq: {mean_f_bilby:.3f} bilby vs {mean_f:.3f} rejection sampling")
print(f"freq: {std_f_bilby:.3f} bilby vs {std_f:.3f} rejection sampling")
print(f"freq: {mean_a_bilby:.3f} bilby vs {mean_a:.3f} rejection sampling")
print(f"freq: {std_a_bilby:.3f} bilby vs {std_a:.3f} rejection sampling")
# Out:
# freq: 1.941 bilby vs 1.941 rejection sampling
# freq: 0.040 bilby vs 0.040 rejection sampling
# freq: 0.347 bilby vs 0.346 rejection sampling
# freq: 0.016 bilby vs 0.016 rejection sampling

# %% [markdown]
# Yes, these results are consistent with one another to within the standard deviation.

# %% [markdown]
# ### Q1.2
# Having the posterior distributions tells us about the parameters, but not if the model is a good fit to the data. For this, it is useful to use a *posterior predictive check*. Create a plot of the raw data (i.e `yobs` against `time`) Then, overlay on it the prediction of your model using the mean for $f$ and $\alpha$ estimated in Q1 (from either method).

# %%
plt.plot(time, yobs, label='data')
model = model_Ms(time, mean_f, mean_a)
plt.plot(time, model, label='mean estimate')
plt.gca().set(xlabel="Time [s]", ylabel="Observed y values [arb. units]")
plt.legend();

# %% [markdown]
# ### Q2.1 (Optional)
# It is more common to show the maximum likelihood fit and some measure of uncertainty. For the maximum likelihood, this can be obtained from the `posterior` data frame as follow:
#
# - First identify the index of the maximum likelihood point `idx_max = np.argmax(result_Ms.posterior.log_likelihood)`
# - Then return the row of the maximum `maxL = result_Ms.posterior.iloc[idx_max]`
# - The values can be accessed with `maxL.freq` for example
#
# A straightforward approach is to draw random samples from $p(\theta| d, M_s)$ and plot these. You can draw a random sample from the bilby posterior using `result.posterior.sample().iloc[0]` (this will give you a single sample with keys for `freq` and `alpha`). Draw 100 samples from the posterior and overplot them alongside your mean estimate. You will want to add `color='C3'`, `zorder=-100` and `alpha=0.1` to the `plot()` command so they don't overwhelm the rest of the plot.

# %%
plt.plot(time, yobs, label='data')


idx_max = np.argmax(result_Ms.posterior.log_likelihood)
maxL = result_Ms.posterior.iloc[idx_max]
maxL_fit = model_Ms(time, maxL.freq, maxL.alpha)
plt.plot(time, maxL_fit, label='maximum likelihood fit')

random_samples = result_Ms.posterior.sample(100)
freqs = np.array(random_samples.freq).reshape(-1, 1)  # Reshape to (n_freqs, 1) for broadcasting
alphas = np.array(random_samples.alpha).reshape(-1, 1)  # Reshape to (n_alphas, 1) for broadcasting
random_fits = model_Ms(time, freqs, alphas)

plt.plot(time, random_fits.T, color='C3', zorder=-100, alpha=0.1)

plt.gca().set(xlabel="Time [s]", ylabel="Observed y values [arb. units]")
plt.legend();

# %% [markdown]
# ### Q3.1 (Optional: hard)
# Your plot from Q2 should tell you that the model isn't  fully explaining the data! You take the plot back to your tame theorist and demand an explanation. They quickly tell you that actually there is a better model where the frequency of the sinusoid is time-dependent:
#
# $$ M_t: s(t) = e^{-(t/\alpha)^2} \sin\left(2\pi (f_0 + \dot{f} \times t) t\right)  $$
#
# This new model has three parameters: $f$, $\dot{f}$ and $\alpha$.
#
# Your task is to program this model in a new function, then run `bilby_mcmc` on it and reproduce the figure from Q3. You will need to define new parameters $f_0$ and $\dot{f}$ in the function (probably best to call it `model_Mt` to be consistent) and add these to the prior. If you are successful, the predicted plot should nicely overlap the data. Along the way you should also create a corner plot: this can be helpful to see if you have chosen appropriate priors.

# %%
def sinusoid(time, freq0, df):
    return np.sin(2 * np.pi * (freq0 + df * time) * time)

def gaussian_exponential(time, alpha):
    return np.exp(-(time/alpha)**2)

def model_Mt(time, freq0, df, alpha):
    return gaussian_exponential(time, alpha) * sinusoid(time, freq0, df)

# %%
likelihood_Mt = bilby.core.likelihood.GaussianLikelihood(time, yobs, model_Mt, sigma=0.1)

priors_Mt = dict(
    freq0=bilby.core.prior.Uniform(0, 5),
    df=bilby.core.prior.Uniform(0, 5),
    alpha=bilby.core.prior.Uniform(0, 1)
)

# %%
result_Mt = bilby.run_sampler(
    likelihood_Mt,
    priors_Mt,
    label="model_Mt",  # A label to help sort our results
    outdir="toy_model",  # The directory where results will be kept
    clean=True,  # Don't use cached data
    sampler="bilby_mcmc",  # Use the bilby_mcmc sampler
    nsamples=1000,  # Draw 1000 samples
    printdt=2,  # Print an update ever 5 seconds
    L1steps=1,  # The number of internal steps to take
)
# Out:
# 13:59 bilby INFO    : Running for label 'model_Mt', output will be saved to 'toy_model'
# 13:59 bilby INFO    : Analysis priors:
# 13:59 bilby INFO    : freq0=Uniform(minimum=0, maximum=5, name=None, latex_label=None, unit=None, boundary=None)
# 13:59 bilby INFO    : df=Uniform(minimum=0, maximum=5, name=None, latex_label=None, unit=None, boundary=None)
# 13:59 bilby INFO    : alpha=Uniform(minimum=0, maximum=1, name=None, latex_label=None, unit=None, boundary=None)
# 13:59 bilby INFO    : Analysis likelihood class: <class 'bilby.core.likelihood.GaussianLikelihood'>
# 13:59 bilby INFO    : Analysis likelihood noise evidence: nan
# 13:59 bilby INFO    : Single likelihood evaluation took 1.952e-04 s
# 13:59 bilby INFO    : Using sampler Bilby_MCMC with kwargs {'nsamples': 1000, 'nensemble': 1, 'pt_ensemble': False, 'ntemps': 1, 'Tmax': None, 'Tmax_from_SNR': 20, 'initial_betas': None, 'adapt': True, 'adapt_t0': 100, 'adapt_nu': 10, 'pt_rejection_sample': False, 'burn_in_nact': 10, 'thin_by_nact': 1, 'fixed_discard': 0, 'autocorr_c': 5, 'L1steps': 1, 'L2steps': 3, 'printdt': 2, 'check_point_delta_t': 1800, 'min_tau': 1, 'proposal_cycle': 'default', 'stop_after_convergence': False, 'fixed_tau': None, 'tau_window': None, 'evidence_method': 'stepping_stone', 'initial_sample_method': 'prior', 'initial_sample_dict': None}
# 13:59 bilby INFO    : Initializing BilbyPTMCMCSampler with:
#   Convergence settings: ConvergenceInputs(autocorr_c=5, burn_in_nact=10, thin_by_nact=1, fixed_discard=0, target_nsamples=1000, stop_after_convergence=False, L1steps=1, L2steps=3, min_tau=1, fixed_tau=None, tau_window=None)
#   Parallel-tempering settings: ParallelTemperingInputs(ntemps=1, nensemble=1, Tmax=None, Tmax_from_SNR=20, initial_betas=None, adapt=True, adapt_t0=100, adapt_nu=10, pt_ensemble=False)
#   proposal_cycle: default
#   pt_rejection_sample: False
# 13:59 bilby INFO    : Setting parallel tempering inputs=ParallelTemperingInputs(ntemps=1, nensemble=1, Tmax=None, Tmax_from_SNR=20, initial_betas=None, adapt=True, adapt_t0=100, adapt_nu=10, pt_ensemble=False)
# 13:59 bilby INFO    : Initializing BilbyPTMCMCSampler with:ntemps=1, nensemble=1, pt_ensemble=False, initial_betas=[1], initial_sample_method=prior, initial_sample_dict=None
#
# 13:59 bilby INFO    : Using initial sample {'freq0': 0.6902266258990075, 'df': 2.4541650308012803, 'alpha': 0.12498609648009851}
# 13:59 bilby INFO    : Using ProposalCycle:
#   AdaptiveGaussianProposal(acceptance_ratio:nan,n:0,scale:1,)
#   DifferentialEvolutionProposal(acceptance_ratio:nan,n:0,)
#   UniformProposal(acceptance_ratio:nan,n:0,)
#   KDEProposal(acceptance_ratio:nan,n:0,trained:0,)
#   FisherMatrixProposal(acceptance_ratio:nan,n:0,scale:1,)
#   GMMProposal(acceptance_ratio:nan,n:0,trained:0,)
#
# 13:59 bilby INFO    : Setting convergence_inputs=ConvergenceInputs(autocorr_c=5, burn_in_nact=10, thin_by_nact=1, fixed_discard=0, target_nsamples=1000, stop_after_convergence=False, L1steps=1, L2steps=3, min_tau=1, fixed_tau=None, tau_window=None)
# 13:59 bilby INFO    : Drawing 1000 samples
# 13:59 bilby INFO    : Checkpoint every check_point_delta_t=1800s
# 13:59 bilby INFO    : Print update every printdt=2s
# 2.49e+03|0:00:02|2.80e+03(10tau)|t=inf|n=0|a=0.16|e=0.0e+00%|0.80ms/ev|maxl=76.14|ETF=-
# 4.78e+03|0:00:04|7.44e+02(z1)|t=34|n=119|a=0.18|e=2.5e+00%|0.91ms/ev|maxl=76.20|ETF=0:00:27
# 5.54e+03|0:00:06|7.44e+02(z1)|t=34|n=142|a=0.21|e=2.6e+00%|2.63ms/ev|maxl=76.20|ETF=0:01:16
# 7.36e+03|0:00:08|7.44e+02(z1)|t=34|n=195|a=0.25|e=2.6e+00%|1.10ms/ev|maxl=76.20|ETF=0:00:30
# 9.25e+03|0:00:10|7.44e+02(z1)|t=34|n=251|a=0.28|e=2.7e+00%|1.06ms/ev|maxl=76.20|ETF=0:00:26
# 1.11e+04|0:00:12|7.44e+02(z1)|t=34|n=307|a=0.30|e=2.8e+00%|1.07ms/ev|maxl=76.20|ETF=0:00:25
# 1.24e+04|0:00:14|7.44e+02(z1)|t=34|n=345|a=0.31|e=2.8e+00%|1.56ms/ev|maxl=76.20|ETF=0:00:34
# 1.32e+04|0:00:16|7.44e+02(z1)|t=34|n=367|a=0.31|e=2.8e+00%|2.66ms/ev|maxl=76.20|ETF=0:00:56
# 1.39e+04|0:00:18|7.44e+02(z1)|t=34|n=389|a=0.32|e=2.8e+00%|2.67ms/ev|maxl=76.20|ETF=0:00:55
# 1.57e+04|0:00:20|7.44e+02(z1)|t=34|n=443|a=0.32|e=2.8e+00%|1.11ms/ev|maxl=76.20|ETF=0:00:20
# 1.74e+04|0:00:22|7.44e+02(z1)|t=34|n=492|a=0.33|e=2.8e+00%|1.19ms/ev|maxl=76.20|ETF=0:00:20
# 1.91e+04|0:00:24|7.44e+02(z1)|t=34|n=544|a=0.34|e=2.8e+00%|1.16ms/ev|maxl=76.20|ETF=0:00:17
# 2.08e+04|0:00:26|7.44e+02(z1)|t=34|n=594|a=0.34|e=2.9e+00%|1.17ms/ev|maxl=76.20|ETF=0:00:16
# 2.20e+04|0:00:28|7.44e+02(z1)|t=34|n=627|a=0.34|e=2.9e+00%|1.79ms/ev|maxl=76.20|ETF=0:00:22
# 2.26e+04|0:00:30|7.44e+02(z1)|t=34|n=645|a=0.34|e=2.9e+00%|3.40ms/ev|maxl=76.20|ETF=0:00:40
# 2.36e+04|0:00:32|7.44e+02(z1)|t=34|n=676|a=0.35|e=2.9e+00%|1.89ms/ev|maxl=76.20|ETF=0:00:20
# 2.55e+04|0:00:34|7.44e+02(z1)|t=34|n=732|a=0.35|e=2.9e+00%|1.06ms/ev|maxl=76.20|ETF=0:00:09
# 2.74e+04|0:00:36|7.44e+02(z1)|t=34|n=787|a=0.35|e=2.9e+00%|1.08ms/ev|maxl=76.20|ETF=0:00:07
# 2.92e+04|0:00:38|7.44e+02(z1)|t=34|n=840|a=0.36|e=2.9e+00%|1.11ms/ev|maxl=76.20|ETF=0:00:06
# 3.10e+04|0:00:40|7.44e+02(z1)|t=34|n=895|a=0.36|e=2.9e+00%|1.08ms/ev|maxl=76.20|ETF=0:00:03
# 3.20e+04|0:00:42|7.44e+02(z1)|t=34|n=924|a=0.36|e=2.9e+00%|2.01ms/ev|maxl=76.20|ETF=0:00:05
# 14:00 bilby WARNING : Non-negligible print progress time (ppt_frac=0.01)
# 3.26e+04|0:00:44|7.44e+02(z1)|t=34|n=943|a=0.36|e=2.9e+00%|3.21ms/ev|maxl=76.20|ETF=0:00:06
# 3.39e+04|0:00:46|7.44e+02(z1)|t=34|n=980|a=0.36|e=2.9e+00%|1.58ms/ev|maxl=76.20|ETF=0:00:01
# 3.57e+04|0:00:48|7.44e+02(z1)|t=34|n=1034|a=0.36|e=2.9e+00%|1.10ms/ev|maxl=76.20|ETF=0
# 14:00 bilby INFO    : Reached convergence: exiting sampling
# 14:00 bilby INFO    : Checkpoint start
# 14:00 bilby INFO    : Written checkpoint file toy_model/model_Mt_resume.pickle
# 14:00 bilby INFO    : Zero-temperature proposals:
# 14:00 bilby INFO    : AdaptiveGaussianProposal(acceptance_ratio:0.23,n:7.1e+03,scale:0.019,)
# 14:00 bilby INFO    : DifferentialEvolutionProposal(acceptance_ratio:0.39,n:6.8e+03,)
# 14:00 bilby INFO    : UniformProposal(acceptance_ratio:1,n:2.5e+02,)
# 14:00 bilby INFO    : KDEProposal(acceptance_ratio:0.12,n:7.5e+03,trained:1,)
# 14:00 bilby INFO    : FisherMatrixProposal(acceptance_ratio:0.44,n:6.7e+03,scale:1,)
# 14:00 bilby INFO    : GMMProposal(acceptance_ratio:0.6,n:7.4e+03,trained:1,)
# 14:00 bilby INFO    : Current taus={'freq0': 8.8, 'df': 9.9, 'alpha': 11.8}
# 14:00 bilby INFO    : Creating diagnostic plots
# 14:00 bilby INFO    : Checkpoint finished
# 14:00 bilby INFO    : Sampling time: 0:00:48.170865
# 14:00 bilby INFO    : Summary of results:
# nsamples: 3179
# ln_noise_evidence:    nan
# ln_evidence:    nan +/-    nan
# ln_bayes_factor:    nan +/-    nan

# %%
result_Mt.plot_corner()

# %%
plt.plot(time, yobs, label='data')


idx_max = np.argmax(result_Mt.posterior.log_likelihood)
maxL = result_Mt.posterior.iloc[idx_max]
maxL_fit = model_Mt(time, maxL.freq0, maxL.df, maxL.alpha)
plt.plot(time, maxL_fit, label='maximum likelihood fit')

random_samples = result_Mt.posterior.sample(100)
freq0s = np.array(random_samples.freq0).reshape(-1, 1)  # Reshape to (n_freqs, 1) for broadcasting
dfs = np.array(random_samples.df).reshape(-1, 1)  # Reshape to (n_freqs, 1) for broadcasting
alphas = np.array(random_samples.alpha).reshape(-1, 1)  # Reshape to (n_alphas, 1) for broadcasting
random_fits = model_Mt(time, freq0s, dfs, alphas)

plt.plot(time, random_fits.T, color='C3', zorder=-100, alpha=0.1)

plt.gca().set(xlabel="Time [s]", ylabel="Observed y values [arb. units]")
plt.legend();

# %% [markdown]
# ### Q3.2 (Optional)
# We can tell already that the $M_t$ model is far better than $M_s$: the posterior predictive fit better explains the data. One can also look at the posterior of $\dot{f}$ from $M_t$: Since $M_s$ is a subset of $M_t$ (i.e. they are equivalent when $\dot{f}=0$) the fact that the the posterior on $\dot{f}$ peaks away from zero tells you that $M_t$ is better than $M_s$.
#
# However, it is fun to also show how we can quantify this using the posterior odds (defined in the first section!). For this, we need to calculate the evidence $\mathcal{Z}(d | M_s)$ and $\mathcal{Z}(d | M_t)$. They can be estimated by stochastic sampling. However, `bilby_mcmc` is not the right tool (in can in principle, but the alternative is superior for evidence calculation). Instead, we should use the **nested sampling** package `dynesty`
#
# - Rerun your analysis of both models, but use `sampler="dynesty"` in `run_sampler`. You will also need to add configuration arguments: `nlive=500, sample="rwalk"`)
# - Calculate the Bayes factor using `np.exp(result_Mt.log_evidence - result_Ms.log_evidence)`

# %%
def sinusoid(time, freq):
    return np.sin(2 * np.pi * freq * time)

def gaussian_exponential(time, alpha):
    return np.exp(-(time/alpha)**2)

def model_Ms(time, freq, alpha):
    return gaussian_exponential(time, alpha) * sinusoid(time, freq)

likelihood_Ms = bilby.core.likelihood.GaussianLikelihood(time, yobs, model_Ms, sigma=0.1)

priors_Ms = dict(
    freq=bilby.core.prior.Uniform(0, 5),
    alpha=bilby.core.prior.Uniform(0, 1)
)

result_Ms = bilby.run_sampler(
    likelihood_Ms,
    priors_Ms,
    label="model_Ms",  # A label to help sort our results
    outdir="toy_model",  # The directory where results will be kept
    clean=True,  # Don't use cached data
    sampler="dynesty",  # Use the dynesty sampler
    nsamples=1000,  # Draw 1000 samples
    printdt=2,  # Print an update ever 5 seconds
    L1steps=1,  # The number of internal steps to take
    nlive=500,
    sample="rwalk",
)
# Out:
# 14:07 bilby INFO    : Running for label 'model_Ms', output will be saved to 'toy_model'
# 14:07 bilby INFO    : Analysis priors:
# 14:07 bilby INFO    : freq=Uniform(minimum=0, maximum=5, name=None, latex_label=None, unit=None, boundary=None)
# 14:07 bilby INFO    : alpha=Uniform(minimum=0, maximum=1, name=None, latex_label=None, unit=None, boundary=None)
# 14:07 bilby INFO    : Analysis likelihood class: <class 'bilby.core.likelihood.GaussianLikelihood'>
# 14:07 bilby INFO    : Analysis likelihood noise evidence: nan
# 14:07 bilby INFO    : Single likelihood evaluation took 1.411e-04 s
# 14:07 bilby WARNING : Supplied argument 'nsamples' not an argument of 'Dynesty', removing.
# 14:07 bilby WARNING : Supplied argument 'printdt' not an argument of 'Dynesty', removing.
# 14:07 bilby WARNING : Supplied argument 'L1steps' not an argument of 'Dynesty', removing.
# 14:07 bilby INFO    : Using sampler Dynesty with kwargs {'nlive': 500, 'bound': 'live', 'sample': 'rwalk', 'periodic': None, 'reflective': None, 'update_interval': 600, 'first_update': None, 'npdim': None, 'rstate': None, 'queue_size': 1, 'pool': None, 'use_pool': None, 'live_points': None, 'logl_args': None, 'logl_kwargs': None, 'ptform_args': None, 'ptform_kwargs': None, 'gradient': None, 'grad_args': None, 'grad_kwargs': None, 'compute_jac': False, 'enlarge': None, 'bootstrap': None, 'walks': 100, 'facc': 0.2, 'slices': None, 'fmove': 0.9, 'max_move': 100, 'update_func': None, 'ncdim': None, 'blob': False, 'save_history': False, 'history_filename': None, 'maxiter': None, 'maxcall': None, 'dlogz': 0.1, 'logl_max': inf, 'n_effective': None, 'add_live': True, 'print_progress': True, 'print_func': <bound method Dynesty._print_func of <bilby.core.sampler.dynesty.Dynesty object at 0x7d185b015ae0>>, 'save_bounds': False, 'checkpoint_file': None, 'checkpoint_every': 60, 'resume': False}
# 14:07 bilby INFO    : Checkpoint every check_point_delta_t = 600s
# 14:07 bilby INFO    : Using dynesty version 2.1.2
# 14:07 bilby INFO    : Using the bilby-implemented rwalk sample method with ACT estimated walks. An average of 4 steps will be accepted up to chain length 5000.
# 14:07 bilby INFO    : Generating initial points from the prior
# 1it [00:00, ?it/s]
# 14:07 bilby INFO    : Written checkpoint file toy_model/model_Ms_resume.pickle
# 14:07 bilby INFO    : Written checkpoint file toy_model/model_Ms_resume.pickle
# 14:07 bilby INFO    : Rejection sampling nested samples to obtain 1347 posterior samples
# 14:07 bilby INFO    : Sampling time: 0:00:26.864535
# 14:07 bilby INFO    : Summary of results:
# nsamples: 1347
# ln_noise_evidence:    nan
# ln_evidence: 18.894 +/-  0.138
# ln_bayes_factor:    nan +/-  0.138

# %%
def sinusoid(time, freq0, df):
    return np.sin(2 * np.pi * (freq0 + df * time) * time)

def gaussian_exponential(time, alpha):
    return np.exp(-(time/alpha)**2)

def model_Mt(time, freq0, df, alpha):
    return gaussian_exponential(time, alpha) * sinusoid(time, freq0, df)

likelihood_Mt = bilby.core.likelihood.GaussianLikelihood(time, yobs, model_Mt, sigma=0.1)

priors_Mt = dict(
    freq0=bilby.core.prior.Uniform(0, 5),
    df=bilby.core.prior.Uniform(0, 5),
    alpha=bilby.core.prior.Uniform(0, 1)
)

result_Mt = bilby.run_sampler(
    likelihood_Mt,
    priors_Mt,
    label="model_Mt",  # A label to help sort our results
    outdir="toy_model",  # The directory where results will be kept
    clean=True,  # Don't use cached data
    sampler="dynesty",  # Use the dynesty sampler
    nsamples=1000,  # Draw 1000 samples
    printdt=2,  # Print an update ever 5 seconds
    L1steps=1,  # The number of internal steps to take
    nlive=500,
    sample="rwalk",
)
# Out:
# 14:09 bilby INFO    : Running for label 'model_Mt', output will be saved to 'toy_model'
# 14:09 bilby INFO    : Analysis priors:
# 14:09 bilby INFO    : freq0=Uniform(minimum=0, maximum=5, name=None, latex_label=None, unit=None, boundary=None)
# 14:09 bilby INFO    : df=Uniform(minimum=0, maximum=5, name=None, latex_label=None, unit=None, boundary=None)
# 14:09 bilby INFO    : alpha=Uniform(minimum=0, maximum=1, name=None, latex_label=None, unit=None, boundary=None)
# 14:09 bilby INFO    : Analysis likelihood class: <class 'bilby.core.likelihood.GaussianLikelihood'>
# 14:09 bilby INFO    : Analysis likelihood noise evidence: nan
# 14:09 bilby INFO    : Single likelihood evaluation took 2.180e-04 s
# 14:09 bilby WARNING : Supplied argument 'nsamples' not an argument of 'Dynesty', removing.
# 14:09 bilby WARNING : Supplied argument 'printdt' not an argument of 'Dynesty', removing.
# 14:09 bilby WARNING : Supplied argument 'L1steps' not an argument of 'Dynesty', removing.
# 14:09 bilby INFO    : Using sampler Dynesty with kwargs {'nlive': 500, 'bound': 'live', 'sample': 'rwalk', 'periodic': None, 'reflective': None, 'update_interval': 600, 'first_update': None, 'npdim': None, 'rstate': None, 'queue_size': 1, 'pool': None, 'use_pool': None, 'live_points': None, 'logl_args': None, 'logl_kwargs': None, 'ptform_args': None, 'ptform_kwargs': None, 'gradient': None, 'grad_args': None, 'grad_kwargs': None, 'compute_jac': False, 'enlarge': None, 'bootstrap': None, 'walks': 100, 'facc': 0.2, 'slices': None, 'fmove': 0.9, 'max_move': 100, 'update_func': None, 'ncdim': None, 'blob': False, 'save_history': False, 'history_filename': None, 'maxiter': None, 'maxcall': None, 'dlogz': 0.1, 'logl_max': inf, 'n_effective': None, 'add_live': True, 'print_progress': True, 'print_func': <bound method Dynesty._print_func of <bilby.core.sampler.dynesty.Dynesty object at 0x7d185bf3beb0>>, 'save_bounds': False, 'checkpoint_file': None, 'checkpoint_every': 60, 'resume': False}
# 14:09 bilby INFO    : Checkpoint every check_point_delta_t = 600s
# 14:09 bilby INFO    : Using dynesty version 2.1.2
# 14:09 bilby INFO    : Using the bilby-implemented rwalk sample method with ACT estimated walks. An average of 4 steps will be accepted up to chain length 5000.
# 14:09 bilby INFO    : Generating initial points from the prior
# 1it [00:00, ?it/s]
# 14:09 bilby INFO    : Written checkpoint file toy_model/model_Mt_resume.pickle
# 14:09 bilby INFO    : Rejection sampling nested samples to obtain 1545 posterior samples
# 14:09 bilby INFO    : Sampling time: 0:00:36.317598
# 14:09 bilby INFO    : Summary of results:
# nsamples: 1545
# ln_noise_evidence:    nan
# ln_evidence: 65.414 +/-  0.170
# ln_bayes_factor:    nan +/-  0.170

# %%
bayes_factor = np.exp(result_Mt.log_evidence - result_Ms.log_evidence)
bayes_factor

# bayes factor >>1, model Mt is preferred
# Out:
# 1.5970079333583906e+20

# %% [markdown]
# ### Q4.1 (Optional: easy)
#
# Throughout all our analyses, we assumed that $\sigma=0.1$. But, what would we do if we didn't know this a priori? One option is to estimate it, you can do this by simply taking the standard deviation of data away from where the transient signal is. First, try to cut out the first 1s of data and use this to estimate $\sigma$, is it close to the true value $0.1$? How about taking the last second of data?

# %%
yobs[time < time.min() + 1].std(), yobs[time > time.max() - 1].std()
# Out:
# (0.12083232379507279, 0.10246210029527959)

# %% [markdown]
# Both are close to 0.1, but there is some scatter.

# %% [markdown]
# ### Q4.2 (Optional: harder)
#
# If we did not know $\sigma$ a priori, and we didn't trust our estimate, we could simply infer it from the data! You can do this by removing the `sigma=0.1` in the `GaussianLikelihood` and setting a prior on sigma. Try this using your $M_t$ model.

# %%
def sinusoid(time, freq0, df):
    return np.sin(2 * np.pi * (freq0 + df * time) * time)

def gaussian_exponential(time, alpha):
    return np.exp(-(time/alpha)**2)

def model_Mt(time, freq0, df, alpha):
    return gaussian_exponential(time, alpha) * sinusoid(time, freq0, df)

likelihood_Mt = bilby.core.likelihood.GaussianLikelihood(time, yobs, model_Mt)

priors_Mt = dict(
    freq0=bilby.core.prior.Uniform(0, 5),
    df=bilby.core.prior.Uniform(0, 5),
    alpha=bilby.core.prior.Uniform(0, 1),
    sigma=bilby.core.prior.Uniform(0, 1)
)

result_Mt = bilby.run_sampler(
    likelihood_Mt,
    priors_Mt,
    label="model_Mt",  # A label to help sort our results
    outdir="toy_model",  # The directory where results will be kept
    clean=True,  # Don't use cached data
    sampler="bilby_mcmc",  # Use the bilby_mcmc sampler
    nsamples=1000,  # Draw 1000 samples
    printdt=2,  # Print an update ever 5 seconds
    L1steps=1,  # The number of internal steps to take
)
# Out:
# 14:15 bilby INFO    : Running for label 'model_Mt', output will be saved to 'toy_model'
# 14:15 bilby INFO    : Analysis priors:
# 14:15 bilby INFO    : freq0=Uniform(minimum=0, maximum=5, name=None, latex_label=None, unit=None, boundary=None)
# 14:15 bilby INFO    : df=Uniform(minimum=0, maximum=5, name=None, latex_label=None, unit=None, boundary=None)
# 14:15 bilby INFO    : alpha=Uniform(minimum=0, maximum=1, name=None, latex_label=None, unit=None, boundary=None)
# 14:15 bilby INFO    : sigma=Uniform(minimum=0, maximum=1, name=None, latex_label=None, unit=None, boundary=None)
# 14:15 bilby INFO    : Analysis likelihood class: <class 'bilby.core.likelihood.GaussianLikelihood'>
# 14:15 bilby INFO    : Analysis likelihood noise evidence: nan
# 14:15 bilby INFO    : Single likelihood evaluation took 4.308e-04 s
# 14:15 bilby INFO    : Using sampler Bilby_MCMC with kwargs {'nsamples': 1000, 'nensemble': 1, 'pt_ensemble': False, 'ntemps': 1, 'Tmax': None, 'Tmax_from_SNR': 20, 'initial_betas': None, 'adapt': True, 'adapt_t0': 100, 'adapt_nu': 10, 'pt_rejection_sample': False, 'burn_in_nact': 10, 'thin_by_nact': 1, 'fixed_discard': 0, 'autocorr_c': 5, 'L1steps': 1, 'L2steps': 3, 'printdt': 2, 'check_point_delta_t': 1800, 'min_tau': 1, 'proposal_cycle': 'default', 'stop_after_convergence': False, 'fixed_tau': None, 'tau_window': None, 'evidence_method': 'stepping_stone', 'initial_sample_method': 'prior', 'initial_sample_dict': None}
# 14:15 bilby INFO    : Initializing BilbyPTMCMCSampler with:
#   Convergence settings: ConvergenceInputs(autocorr_c=5, burn_in_nact=10, thin_by_nact=1, fixed_discard=0, target_nsamples=1000, stop_after_convergence=False, L1steps=1, L2steps=3, min_tau=1, fixed_tau=None, tau_window=None)
#   Parallel-tempering settings: ParallelTemperingInputs(ntemps=1, nensemble=1, Tmax=None, Tmax_from_SNR=20, initial_betas=None, adapt=True, adapt_t0=100, adapt_nu=10, pt_ensemble=False)
#   proposal_cycle: default
#   pt_rejection_sample: False
# 14:15 bilby INFO    : Setting parallel tempering inputs=ParallelTemperingInputs(ntemps=1, nensemble=1, Tmax=None, Tmax_from_SNR=20, initial_betas=None, adapt=True, adapt_t0=100, adapt_nu=10, pt_ensemble=False)
# 14:15 bilby INFO    : Initializing BilbyPTMCMCSampler with:ntemps=1, nensemble=1, pt_ensemble=False, initial_betas=[1], initial_sample_method=prior, initial_sample_dict=None
#
# 14:15 bilby INFO    : Using initial sample {'freq0': 0.3101928420418376, 'df': 4.971733757369905, 'alpha': 0.841650963379966, 'sigma': 0.5899296950038024}
# 14:15 bilby INFO    : Using ProposalCycle:
#   AdaptiveGaussianProposal(acceptance_ratio:nan,n:0,scale:1,)
#   DifferentialEvolutionProposal(acceptance_ratio:nan,n:0,)
#   UniformProposal(acceptance_ratio:nan,n:0,)
#   KDEProposal(acceptance_ratio:nan,n:0,trained:0,)
#   FisherMatrixProposal(acceptance_ratio:nan,n:0,scale:1,)
#   GMMProposal(acceptance_ratio:nan,n:0,trained:0,)
#
# 14:15 bilby INFO    : Setting convergence_inputs=ConvergenceInputs(autocorr_c=5, burn_in_nact=10, thin_by_nact=1, fixed_discard=0, target_nsamples=1000, stop_after_convergence=False, L1steps=1, L2steps=3, min_tau=1, fixed_tau=None, tau_window=None)
# 14:15 bilby INFO    : Drawing 1000 samples
# 14:15 bilby INFO    : Checkpoint every check_point_delta_t=1800s
# 14:15 bilby INFO    : Print update every printdt=2s
# 2.06e+03|0:00:02|2.68e+03(10tau)|t=inf|n=0|a=0.11|e=0.0e+00%|0.98ms/ev|maxl=77.17|ETF=-
# 4.79e+03|0:00:04|1.10e+03(z1)|t=77|n=48|a=0.14|e=1.0e+00%|0.73ms/ev|maxl=77.32|ETF=0:00:53
# 14:15 bilby WARNING : Non-negligible print progress time (ppt_frac=0.01)
# 5.29e+03|0:00:06|1.10e+03(z1)|t=77|n=54|a=0.15|e=1.0e+00%|4.07ms/ev|maxl=77.32|ETF=0:04:55
# 5.71e+03|0:00:08|1.10e+03(z1)|t=77|n=60|a=0.17|e=1.1e+00%|4.79ms/ev|maxl=77.32|ETF=0:05:45
# 6.13e+03|0:00:10|1.10e+03(z1)|t=77|n=65|a=0.18|e=1.1e+00%|4.68ms/ev|maxl=77.38|ETF=0:05:35
# 7.14e+03|0:00:12|1.10e+03(z1)|t=77|n=78|a=0.20|e=1.1e+00%|1.99ms/ev|maxl=77.41|ETF=0:02:20
# 7.68e+03|0:00:14|1.10e+03(z1)|t=77|n=85|a=0.21|e=1.1e+00%|3.69ms/ev|maxl=77.41|ETF=0:04:19
# 8.12e+03|0:00:16|1.10e+03(z1)|t=77|n=91|a=0.22|e=1.1e+00%|4.59ms/ev|maxl=77.41|ETF=0:05:20
# 9.69e+03|0:00:18|1.10e+03(z1)|t=77|n=111|a=0.24|e=1.1e+00%|1.27ms/ev|maxl=77.43|ETF=0:01:26
# 1.13e+04|0:00:20|1.10e+03(z1)|t=77|n=133|a=0.25|e=1.2e+00%|1.21ms/ev|maxl=77.43|ETF=0:01:20
# 1.30e+04|0:00:22|1.10e+03(z1)|t=77|n=155|a=0.26|e=1.2e+00%|1.21ms/ev|maxl=77.45|ETF=0:01:18
# 1.46e+04|0:00:24|1.10e+03(z1)|t=77|n=176|a=0.27|e=1.2e+00%|1.23ms/ev|maxl=77.45|ETF=0:01:18
# 1.59e+04|0:00:26|1.10e+03(z1)|t=77|n=192|a=0.27|e=1.2e+00%|1.62ms/ev|maxl=77.45|ETF=0:01:40
# 1.64e+04|0:00:28|1.10e+03(z1)|t=77|n=199|a=0.27|e=1.2e+00%|3.41ms/ev|maxl=77.45|ETF=0:03:29
# 1.71e+04|0:00:30|1.10e+03(z1)|t=77|n=208|a=0.28|e=1.2e+00%|3.07ms/ev|maxl=77.45|ETF=0:03:06
# 1.88e+04|0:00:32|1.10e+03(z1)|t=77|n=231|a=0.28|e=1.2e+00%|1.15ms/ev|maxl=77.45|ETF=0:01:07
# 2.05e+04|0:00:34|1.10e+03(z1)|t=77|n=253|a=0.29|e=1.2e+00%|1.18ms/ev|maxl=77.45|ETF=0:01:07
# 2.22e+04|0:00:36|1.10e+03(z1)|t=77|n=275|a=0.29|e=1.2e+00%|1.18ms/ev|maxl=77.45|ETF=0:01:05
# 2.39e+04|0:00:38|1.10e+03(z1)|t=77|n=296|a=0.29|e=1.2e+00%|1.21ms/ev|maxl=77.45|ETF=0:01:05
# 2.51e+04|0:00:40|1.10e+03(z1)|t=77|n=313|a=0.29|e=1.2e+00%|1.61ms/ev|maxl=77.45|ETF=0:01:24
# 2.56e+04|0:00:42|1.10e+03(z1)|t=77|n=319|a=0.29|e=1.2e+00%|4.00ms/ev|maxl=77.45|ETF=0:03:28
# 2.64e+04|0:00:44|1.10e+03(z1)|t=77|n=329|a=0.29|e=1.2e+00%|2.70ms/ev|maxl=77.45|ETF=0:02:18
# 2.81e+04|0:00:46|1.10e+03(z1)|t=77|n=351|a=0.29|e=1.3e+00%|1.18ms/ev|maxl=77.46|ETF=0:00:58
# 2.97e+04|0:00:48|1.10e+03(z1)|t=77|n=372|a=0.29|e=1.3e+00%|1.26ms/ev|maxl=77.46|ETF=0:01:00
# 3.13e+04|0:00:50|1.10e+03(z1)|t=77|n=393|a=0.30|e=1.3e+00%|1.24ms/ev|maxl=77.46|ETF=0:00:57
# 3.28e+04|0:00:52|1.10e+03(z1)|t=77|n=413|a=0.30|e=1.3e+00%|1.27ms/ev|maxl=77.46|ETF=0:00:57
# 3.39e+04|0:00:54|1.10e+03(z1)|t=77|n=428|a=0.30|e=1.3e+00%|1.84ms/ev|maxl=77.46|ETF=0:01:20
# 3.45e+04|0:00:56|1.10e+03(z1)|t=16|n=2142|a=0.30|e=6.2e+00%|3.46ms/ev|maxl=77.46|ETF=0
# 14:16 bilby WARNING : Non-negligible print progress time (ppt_frac=0.06)
# 14:16 bilby INFO    : Reached convergence: exiting sampling
# 14:16 bilby INFO    : Checkpoint start
# 14:16 bilby INFO    : Written checkpoint file toy_model/model_Mt_resume.pickle
# 14:16 bilby INFO    : Zero-temperature proposals:
# 14:16 bilby INFO    : AdaptiveGaussianProposal(acceptance_ratio:0.23,n:5.9e+03,scale:0.019,)
# 14:16 bilby INFO    : DifferentialEvolutionProposal(acceptance_ratio:0.34,n:6.9e+03,)
# 14:16 bilby INFO    : UniformProposal(acceptance_ratio:1,n:3.1e+02,)
# 14:16 bilby INFO    : KDEProposal(acceptance_ratio:0.039,n:7.2e+03,trained:1,)
# 14:16 bilby INFO    : FisherMatrixProposal(acceptance_ratio:0.36,n:6.9e+03,scale:1,)
# 14:16 bilby INFO    : GMMProposal(acceptance_ratio:0.49,n:7.2e+03,trained:1,)
# 14:16 bilby INFO    : Current taus={'freq0': 9.5, 'df': 13.1, 'alpha': 15.6, 'sigma': 14.2}
# 14:16 bilby INFO    : Creating diagnostic plots
# 14:16 bilby INFO    : Checkpoint finished
# 14:16 bilby INFO    : Sampling time: 0:00:56.120416
# 14:16 bilby INFO    : Summary of results:
# nsamples: 2228
# ln_noise_evidence:    nan
# ln_evidence:    nan +/-    nan
# ln_bayes_factor:    nan +/-    nan

# %%
result_Mt.plot_corner()
